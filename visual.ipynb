# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data for the histogram data = np.random.randn(1000)
data = np.random.randn(1000)
# Plotting a basic histogram
plt.hist(data, bins=30, color='skyblue', edgecolor='black')

# Adding labels and title plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')

# Display the plot plt.show()
plt.show()




import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Generate random data for the histogram
data = np.random.randn(1000)

# Creating a customized histogram with a density plot
sns.histplot(data, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('Customized Histogram with Density Plot')

# Display the plot
plt.show()





# Import libraries
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
cars = ['AUDI', 'BMW', 'FORD',
'TESLA', 'JAGUAR', 'MERCEDES']
data = [23, 17, 35, 29, 12, 41]
# Creating plot
fig = plt.figure(figsize=(10, 7))
plt.pie(data, labels=cars)

# show plot
plt.show()




import matplotlib.pyplot as plt
import numpy as np
x_axis_value = np.array([4, 9, 6, 7, 12, 13, 21, 19, 4, 11, 22, 18, 6])
y_axis_value = np.array([90, 80, 89, 88, 101, 82, 102, 80, 91, 76, 77, 88, 66])
#plot basic scatter value in python
plt.scatter(x_axis_value, y_axis_value)
x_axis_value = np.array([5, 12, 8, 11, 16, 8, 2, 18, 7, 3, 21, 14, 17, 24, 12])
y_axis_value = np.array([101, 106, 85, 105, 90, 98, 90, 95, 94, 99, 78, 118, 99, 88, 85])
#plot basic scatter value in python
plt.scatter(x_axis_value, y_axis_value)
plt.show()



# import the library import seaborn as sns
import seaborn as sns
# load the dataset
dataset = sns.load_dataset('tips')

# the first five entries of the dataset dataset.head()
dataset.head()

sns.set_style('whitegrid')
sns.lmplot(x ='total_bill', y ='tip', data = dataset)
plt.show()
